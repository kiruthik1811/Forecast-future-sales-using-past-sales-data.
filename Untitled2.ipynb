# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pylab import rcParams

# %%
# #Creating pandas df
df = pd.read_csv('Shampoo.csv')

# %%
df.shape
# Out:
# (36, 2)

# %%
df.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
df.tail()
# Out:
#    Month  Sales
# 31  3-08  407.6
# 32  3-09  682.0
# 33  3-10  475.3
# 34  3-11  581.3
# 35  3-12  646.9

# %%
date = pd.date_range(start='1/1/2001', end='12/31/2003', freq='M')
date
# Out:
# C:\Users\kirut\AppData\Local\Temp\ipykernel_25924\4051903570.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   date = pd.date_range(start='1/1/2001', end='12/31/2003', freq='M')
# DatetimeIndex(['2001-01-31', '2001-02-28', '2001-03-31', '2001-04-30',
#                '2001-05-31', '2001-06-30', '2001-07-31', '2001-08-31',
#                '2001-09-30', '2001-10-31', '2001-11-30', '2001-12-31',
#                '2002-01-31', '2002-02-28', '2002-03-31', '2002-04-30',
#                '2002-05-31', '2002-06-30', '2002-07-31', '2002-08-31',
#                '2002-09-30', '2002-10-31', '2002-11-30', '2002-12-31',
#                '2003-01-31', '2003-02-28', '2003-03-31', '2003-04-30',
#                '2003-05-31', '2003-06-30', '2003-07-31', '2003-08-31',
#                '2003-09-30', '2003-10-31', '2003-11-30', '2003-12-31'],
#               dtype='datetime64[ns]', freq='ME')

# %%
df['Time_Stamp'] = pd.DataFrame(date,columns=['Date'])
df.head()
df.tail()
# Out:
#    Month  Sales Time_Stamp
# 31  3-08  407.6 2003-08-31
# 32  3-09  682.0 2003-09-30
# 33  3-10  475.3 2003-10-31
# 34  3-11  581.3 2003-11-30
# 35  3-12  646.9 2003-12-31

# %%
df = df.set_index('Time_Stamp')
df.head()
# Out:
#            Month  Sales
# Time_Stamp
# 2001-01-31  1-01  266.0
# 2001-02-28  1-02  145.9
# 2001-03-31  1-03  183.1
# 2001-04-30  1-04  119.3
# 2001-05-31  1-05  180.3

# %%
df_final = df.drop(['Month'], axis=1)
df_final.head()
# Out:
#             Sales
# Time_Stamp
# 2001-01-31  266.0
# 2001-02-28  145.9
# 2001-03-31  183.1
# 2001-04-30  119.3
# 2001-05-31  180.3

# %%
df_final.plot(figsize=(20,8))
plt.grid();
plt.xlabel('Timestamp',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.legend(fontsize="x-large")

# %%
df_final.isnull().sum()
# Out:
# Sales    0
# dtype: int64

# %%
round(df_final.describe(),3)
# Out:
#          Sales
# count   36.000
# mean   312.600
# std    148.937
# min    119.300
# 25%    192.450
# 50%    280.150
# 75%    411.100
# max    682.000

# %%
_, ax = plt.subplots(figsize=(22,8))
sns.boxplot(x = df_final.index.year,y = df_final.values[:,0],ax=ax)
plt.grid();
plt.xlabel('Years',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.legend(fontsize="x-large")
# Out:
# C:\Users\kirut\AppData\Local\Temp\ipykernel_25924\616703590.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize="x-large")

# %%
_, ax = plt.subplots(figsize=(22,8))
sns.boxplot(x = df_final.index.month_name(),y = df_final.values[:,0],ax=ax)

plt.grid();
plt.xlabel('Month',fontsize=15)
plt.ylabel('Yearly Wine Sales Variation',fontsize=15)
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.legend(fontsize="x-large")
# Out:
# C:\Users\kirut\AppData\Local\Temp\ipykernel_25924\4047476488.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize="x-large")

# %%
monthly_sales_across_years = pd.pivot_table(df_final, values = 'Sales', columns = df_final.index.month_name(), index = df_final.index.year)
monthly_sales_across_years
# Out:
# Time_Stamp  April  August  December  February  January   July   June  March  \
# Time_Stamp
# 2001        119.3   224.5     185.9     145.9    266.0  231.8  168.5  183.1
# 2002        273.3   303.6     342.3     149.5    194.3  226.0  287.0  210.1
# 2003        439.3   407.6     646.9     440.4    339.7  575.5  437.4  315.9
#
# Time_Stamp    May  November  October  September
# Time_Stamp
# 2001        180.3     336.5    122.9      192.8
# 2002        191.4     264.5    421.6      289.9
# 2003        401.3     581.3    475.3      682.0

# %%
monthly_sales_across_years.plot(figsize=(20,10))
plt.grid()
plt.legend(loc='best');
plt.xlabel('Years',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.legend(fontsize="x-large")

# %%
quarterly_turnover = pd.pivot_table(df_final, values = "Sales", columns = df_final.index.quarter, index = df_final.index.year)
quarterly_turnover
# Out:
# Time_Stamp           1           2           3           4
# Time_Stamp
# 2001        198.333333  156.033333  216.366667  215.100000
# 2002        184.633333  250.566667  273.166667  342.800000
# 2003        365.333333  426.000000  555.033333  567.833333

# %%
quarterly_turnover.plot(figsize=(20,10))
plt.grid()
plt.legend(loc='best');

plt.xlabel('Years',fontsize=15)
plt.ylabel('Sale Variation',fontsize=15)
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.legend(fontsize="x-large")

# %%
pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (2.2.2)
# Collecting patsy>=0.5.6 (from statsmodels)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\kirut\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.16.0)
# Downloading statsmodels-0.14.4-cp312-cp312-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.8 MB 2.8 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.8 MB 3.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.8 MB 3.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.9/9.8 MB 3.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/9.8 MB 3.6 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.8 MB 3.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.8 MB 4.1 MB/s eta 0:00:02
#    --------------------------- ------------ 6.8/9.8 MB 4.2 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.8 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.8 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 4.3 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-1.0.1 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pylab import rcParams

rcParams['figure.figsize'] =17,8

from statsmodels.graphics.tsaplots import month_plot
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
month_plot(df_final['Sales'],ylabel='Sales')
plt.grid();

# %%
from statsmodels.distributions.empirical_distribution import ECDF

plt.figure(figsize = (18, 8))
cdf = ECDF(df_final['Sales'])
plt.plot(cdf.x, cdf.y, label = "statmodels");
plt.grid()
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.xlabel('Sales', fontsize = 15);

# %%
average    = df_final.groupby(df_final.index)["Sales"].mean()
pct_change = df_final.groupby(df_final.index)["Sales"].sum().pct_change()

fig, (axis1,axis2) = plt.subplots(2,1,sharex=True,figsize=(15,8))

# plot average Customers over time(year-month)
ax1 = average.plot(legend=True,ax=axis1,marker='o',title="Average Rose Sales",grid=True)
ax1.set_xticks(range(len(average)))
ax1.set_xticklabels(average.index.tolist())
# plot precent change for Customers over time(year-month)
ax2 = pct_change.plot(legend=True,ax=axis2,marker='o',colormap="summer",title="Sales Percent Change",grid=True)

# %%
fig, (axis1) = plt.subplots(1,figsize=(15,4))

sns.barplot(x=df_final.index.year, y=df_final.values[:,0], data=df_final, ax=axis1);
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=15)
plt.xlabel('Year', fontsize = 15);
plt.ylabel('Avg Monthly Sales', fontsize = 15);

# %%
x
